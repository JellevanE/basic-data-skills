# %% [markdown]
# # Notebook 1: Python Basics — Values and Variables
# **Time: 45-60 minutes**
#
# ### What you'll learn
# - Understand variables and assignment
# - Work with text (strings), numbers, and booleans
# - Use f-strings to build dynamic text
# - Use `print()` and `type()` for inspection
# - Understand what `import` does

# %% [markdown]
# ---
# ## 1.1 Variables: giving names to things
#
# Variables store values so you can use them later. The name goes on the left, the value on the right.

# %%
country_name = "Netherlands"
population = 17000000
is_in_europe = True

print(country_name)
print(population)
print(is_in_europe)
# Out:
# Netherlands
# 17000000
# True

# %% [markdown]
# **Exercise:** Create variables for your home country: its name, population, and whether it borders the sea.
#
# Use these exact variable names so the checkpoint can validate your work:
# - `my_country` (string)
# - `my_population` (number)
# - `borders_sea` (boolean)

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## 1.2 Text (strings)
#
# Strings are text, wrapped in quotes. You can use either single or double quotes.

# %%
country = "Netherlands"
capital = 'Amsterdam'    # Single or double quotes both work

# Useful operations
print(len(country))              # 11 (number of characters)
print(country.lower())           # "netherlands"
print(country.upper())           # "NETHERLANDS"
print("land" in country)         # True (checks if "land" appears in the text)
# Out:
# 11
# netherlands
# NETHERLANDS
# True

# %% [markdown]
# **Exercise:** Create a string with your city name. Check its length. Check whether it contains the letter "a".
#
# Use these exact variable names:
# - `city` (string)
# - `city_length` (number from `len(city)`)
# - `city_has_a` (boolean from checking whether "a" appears in your city name, case-insensitive)

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## 1.3 Numbers
#
# Python has two types of numbers: **integers** (whole numbers) and **floats** (decimals). Most of the time you don't need to worry about the difference.

# %%
population = 17000000      # Integer (whole number)
latitude = 52.37           # Float (decimal number)

# Basic math
print(population / 1000000)       # 17.0
print(latitude + 1)               # 53.37
print(round(52.3789, 2))          # 52.38
# Out:
# 17.0
# 53.37
# 52.38

# %% [markdown]
# **Exercise:** The Netherlands has a population of 17,000,000 and an area of 41,543 km². Calculate the population density (population divided by area). Round it to 1 decimal.
#
# Store your result in a variable named `density`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## 1.4 Booleans
#
# Booleans are `True` or `False`. They're used for yes/no decisions.

# %%
is_in_europe = True
has_coastline = True
population_over_100m = False

print(is_in_europe)
print(population_over_100m)
# Out:
# True
# False

# %% [markdown]
# You'll see booleans in API responses and use them for filtering data later.

# %% [markdown]
# ---
# ## 1.5 Checking types with `type()`
#
# When something unexpected happens, `type()` helps you understand what you're looking at.

# %%
print(type("Netherlands"))   # <class 'str'>
print(type(17000000))        # <class 'int'>
print(type(52.37))           # <class 'float'>
print(type(True))            # <class 'bool'>
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# This becomes very useful when debugging API responses — "is this a number or a string that looks like a number?"

# %% [markdown]
# ---
# ## 1.6 f-strings: building dynamic text
#
# f-strings let you insert variables into text. Put `f` before the opening quote and variables inside `{}`.

# %%
country = "Netherlands"
population = 17000000

print(f"The population of {country} is {population}")

# You can also do calculations inside the braces
print(f"That's {population / 1000000} million people")
# Out:
# The population of Netherlands is 17000000
# That's 17.0 million people

# %% [markdown]
# You'll use f-strings constantly — for printing results, building messages, and formatting output.
#
# **Exercise:** Create variables for a country's name, capital, and population. Print a sentence like:
# "The capital of Netherlands is Amsterdam. It has 17.0 million people."
#
# Use these exact variable names:
# - `country`
# - `capital`
# - `population`
# - `intro_sentence` (the final f-string sentence)

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## 1.7 Imports: using other people's code
#
# Python has a huge ecosystem of **libraries** — code that other people wrote so you don't have to. You load them with `import`.

# %%
import math
print(math.sqrt(144))    # 12.0 — square root

import datetime
print(datetime.date.today())  # Today's date
# Out:
# 12.0
# 2026-03-03

# %% [markdown]
# Later in this course, you'll use:
# - `import requests` — for calling APIs
# - `import pandas` — for working with data tables
# - `import json` — for reading/writing JSON files
#
# The pattern is always the same: `import library_name`, then use it with `library_name.something()`.

# %% [markdown]
# ---
# ## 1.8 Checkpoint
#
# Run this cell to verify your understanding. If all checks pass, you're ready to move on!

# %%
# Run this cell to check your understanding

required_vars = [
    "my_country",
    "my_population",
    "borders_sea",
    "city",
    "city_length",
    "city_has_a",
    "density",
    "country",
    "capital",
    "population",
    "intro_sentence",
]

missing = [name for name in required_vars if name not in globals()]
assert not missing, (
    "You're missing variables from the exercises: " + ", ".join(missing) + 
    ". Complete the exercise cells first, then run this checkpoint again."
)

assert isinstance(my_country, str), "`my_country` should be a string"
assert isinstance(my_population, (int, float)), "`my_population` should be a number"
assert isinstance(borders_sea, bool), "`borders_sea` should be True or False"

assert isinstance(city, str), "`city` should be a string"
assert city_length == len(city), "`city_length` should be `len(city)`"
assert city_has_a == ("a" in city.lower()), "`city_has_a` should check for 'a' case-insensitively"

assert round(density, 1) == 409.2, "`density` should be 409.2"

assert isinstance(country, str), "`country` should be a string"
assert isinstance(capital, str), "`capital` should be a string"
assert isinstance(population, (int, float)), "`population` should be a number"
assert isinstance(intro_sentence, str), "`intro_sentence` should be text"
assert country in intro_sentence and capital in intro_sentence, (
    "`intro_sentence` should include both country and capital"
)
assert "million" in intro_sentence.lower(), "`intro_sentence` should mention 'million'"

notebook1_ready_for_clue = True
print("All checks passed! ✅ You unlocked Clue 1.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 18
#       3 required_vars = [
#       4     "my_country",
#       5     "my_population",
#    (...)     14     "intro_sentence",
#      15 ]
#      17 missing = [name for name in required_vars if name not in globals()]
# ---> 18 assert not missing, (
#      19     "You're missing variables from the exercises: " + ", ".join(missing) +
#      20     ". Complete the exercise cells first, then run this checkpoint again."
#      21 )
#      23 assert isinstance(my_country, str), "`my_country` should be a string"
#      24 assert isinstance(my_population, (int, float)), "`my_population` should be a number"
#
# AssertionError: You're missing variables from the exercises: my_country, my_population, borders_sea, city, city_length, city_has_a, intro_sentence. Complete the exercise cells first, then run this checkpoint again.

# %% [markdown]
# ---
# ## 1.9 Data Detective Challenge — Clue 1
#
# Throughout this course, you'll collect clues in the **Data Detective Challenge**. Each notebook has one clue. Collect them all to unlock the final certificate in Notebook 6!

# %%
# CHALLENGE: Compute the latitude of Amsterdam
# Amsterdam's latitude is 52 degrees and 0.37 of the next degree.
# Add these two numbers together and round to 2 decimal places.

# Write your solution in the next line:
clue_1 = None  # Replace None with your calculation, e.g. round(..., 2)

# --- Verification ---
if not globals().get("notebook1_ready_for_clue", False):
    print("Complete and pass the checkpoint first to unlock Clue 1.")
elif clue_1 is None:
    print("Add your calculation to `clue_1` first, then run this cell again.")
elif round(float(clue_1), 2) == 52.37:
    print(f"Your answer: {clue_1}")
    print("\n>>> Clue 1 collected!")
    print("Write down: clue_1 =", round(float(clue_1), 2))
    print("You'll need this for the final challenge in Notebook 6.")
else:
    print(f"Your answer: {clue_1}")
    print("Not quite — reread the instructions carefully.")
# Out:
# Complete and pass the checkpoint first to unlock Clue 1.

# %% [markdown]
# ---
# **Next up:** [Notebook 2 — Python Basics: Collections and Loops](2_python_collections_and_loops.ipynb)
